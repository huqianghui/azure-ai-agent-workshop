# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from azure.ai.projects.models import BingGroundingTool,CodeInterpreterTool

from dotenv import load_dotenv
import os
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import BingGroundingTool
from azure.identity import DefaultAzureCredential


# Load environment variables from a .env file
load_dotenv("/home/azureuser/azure-ai-agent-workshop/.env")
# Out:
# True

# %%
model_client=AzureOpenAIChatCompletionClient(
            model=os.getenv("AZURE_OPENAI_MODEL"),
            azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
            api_key=os.getenv("AZURE_OPENAI_KEY"),
            azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
            api_version=os.getenv("AZUER_OPENAI_API_VERSION")
        )

# %%
project_client = AIProjectClient.from_connection_string(
    credential=DefaultAzureCredential(),
    conn_str=os.environ["PROJECT_CONNECTION_STRING"],
)

# %%
from azure.ai.projects.models import (
    AsyncToolSet,
    BingGroundingTool,
    CodeInterpreterTool
)

toolset = AsyncToolSet()

# Add the code interpreter tool
code_interpreter = CodeInterpreterTool()
toolset.add(code_interpreter)

API_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_DEPLOYMENT")

# %%
async def data_science_ai_agent(query: str) -> str:
    print("This is caculator for Azure AI Agent Service .......")
    
    with project_client:
        agent = project_client.agents.create_agent(
            model=API_DEPLOYMENT_NAME,
            name="Data Science AI Agent",
            instructions="Your role is to assist users with  data science. You are professional about machine learning, AI and so on. You also  can use the code interpreter the validate content when there are some algorithem.",
            toolset=toolset,
            temperature=0.2,
            headers={"x-ms-enable-preview": "true"},
        )
        print(f"Created agent, ID: {agent.id}")

        # Create thread for communication
        thread = project_client.agents.create_thread()
        print(f"Created thread, ID: {thread.id}")

        # Create message to thread
        message = project_client.agents.create_message(
            thread_id=thread.id,
            role="user",
            content=query,
        )
        print(f"SMS: {message}")
        # Create and process agent run in thread with tools
        run = project_client.agents.create_and_process_run(thread_id=thread.id, assistant_id=agent.id)
        print(f"Run finished with status: {run.status}")

        if run.status == "failed":
            print(f"Run failed: {run.last_error}")

        # Delete the assistant when done
        project_client.agents.delete_agent(agent.id)
        print("Deleted agent")

        # Fetch and log all messages
        messages = project_client.agents.list_messages(thread_id=thread.id)
        print("Messages:"+ messages["data"][0]["content"][0]["text"]["value"])
    return messages["data"][0]["content"][0]["text"]["value"]

# %%
async def save_blog_agent(blog_content: str) -> str:

    print("This is Code Interpreter for Azure AI Agent Service .......")


    code_interpreter = CodeInterpreterTool()
        
    agent = project_client.agents.create_agent(
            model=API_DEPLOYMENT_NAME,
            name="my-agent",
            instructions="You are helpful agent",
            tools=code_interpreter.definitions,
    )

    thread = project_client.agents.create_thread()

    message = project_client.agents.create_message(
            thread_id=thread.id,
            role="user",
            content="""
        
                    You are my Python programming assistant. Generate code,save """+ blog_content +
                    
                """    
                    and execute it according to the following requirements

                    1. Save blog content to blog-{YYMMDDHHMMSS}.md

                    2. give me the download this file link
                """,
    )
    # create and execute a run
    run = project_client.agents.create_and_process_run(thread_id=thread.id, assistant_id=agent.id)
    print(f"Run finished with status: {run.status}")

    if run.status == "failed":
            # Check if you got "Rate limit is exceeded.", then you want to get more quota
        print(f"Run failed: {run.last_error}")

    # print the messages from the agent
    messages = project_client.agents.get_messages(thread_id=thread.id)
    print(f"Messages: {messages}")

        # get the most recent message from the assistant
    last_msg = messages.get_last_text_message_by_sender("assistant")
    if last_msg:
        print(f"Last Message: {last_msg.text.value}")

        # print(f"File: {messages.file_path_annotations}")


    for file_path_annotation in messages.file_path_annotations:

        file_name = os.path.basename(file_path_annotation.text)

        project_client.agents.save_file(file_id=file_path_annotation.file_path.file_id, file_name=file_name,target_dir="./blog")
        

    project_client.agents.delete_agent(agent.id)
    print("Deleted agent")
    return "Saved"

# %%
data_science_agent = AssistantAgent(
    name="data_science_agent",
    model_client=model_client,
    tools=[data_science_ai_agent],
    system_message="You are a search expert, help me use tools to find relevant knowledge",
)

# %%
save_blog_content_agent = AssistantAgent(
    name="save_blog_content_agent",
    model_client=model_client,
    tools=[save_blog_agent],
    system_message="""
        Save blog content. Respond with 'Saved' to when your blog are saved.
    """
)

# %%
write_agent = AssistantAgent(
    name="write_agent",
    model_client=model_client,
    system_message="""
        You are a blog writer, please help me write a blog based on bing search content."
    """
)

# %%
text_termination = TextMentionTermination("Saved")
# Define a termination condition that stops the task after 5 messages.
max_message_termination = MaxMessageTermination(10)
# Combine the termination conditions using the `|`` operator so that the
# task stops when either condition is met.
termination = text_termination | max_message_termination

# %%
reflection_team = RoundRobinGroupChat([data_science_agent, write_agent,save_blog_content_agent], termination_condition=termination)

# %%
await Console(
    reflection_team.run_stream(task="""

                    I am writing a blog about machine learning. Search for the following 3 questions and write a Chinese blog based on the search results ,save it
                    
                    1. What is Machine Learning?
                    2. The difference between AI and ML
                    3. The history of Machine Learning
                               

    """)
)  # Stream the messages to the console.
# Out:
# ---------- user ----------
#
#
#                     I am writing a blog about machine learning. Search for the following 3 questions and write a Chinese blog based on the search results ,save it
#
#                     1. What is Machine Learning?
#                     2. The difference between AI and ML
#                     3. The history of Machine Learning
#
#
#
# This is caculator for Azure AI Agent Service .......
# Created agent, ID: asst_fRYkYKfiFEnY8L9BqNQECNIB
# Created thread, ID: thread_Mo40PFL4gNWiuHDaH11DyC29
# SMS: {'id': 'msg_RmZMZMyZkjyRjVT8JzQ04KDB', 'object': 'thread.message', 'created_at': 1737369672, 'assistant_id': None, 'thread_id': 'thread_Mo40PFL4gNWiuHDaH11DyC29', 'run_id': None, 'role': 'user', 'content': [{'type': 'text', 'text': {'value': 'What is Machine Learning?', 'annotations': []}}], 'attachments': [], 'metadata': {}}
# Run finished with status: RunStatus.COMPLETED
# Deleted agent
# Messages:Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machine learning systems learn from data, identify patterns, and make decisions based on that data.
#
# Key concepts in machine learning include:
#
# 1. **Data**: The foundation of machine learning. Data can be structured (like tables) or unstructured (like images or text).
#
# 2. **Algorithms**: These are the mathematical models that process the data. Common types of algorithms include:
#    - Supervised Learning: The model is trained on labeled data (input-output pairs).
#    - Unsupervised Learning: The model is trained on unlabeled data and must find patterns or groupings on its own.
#    - Reinforcement Learning: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties.
#
# 3. **Training**: The process of feeding data into a machine learning algorithm to help it learn. This often involves adjusting parameters to minimize errors in predictions.
#
# 4. **Testing and Validation**: After training, the model is tested on new data to evaluate its performance. This helps ensure that the model generalizes well to unseen data.
#
# 5. **Applications**: Machine learning is used in various fields, including:
#    - Natural Language Processing (NLP)
#    - Computer Vision
#    - Recommendation Systems
#    - Fraud Detection
#    - Autonomous Vehicles
#
# Overall, machine learning enables systems to improve their performance over time as they are exposed to more data.
# This is caculator for Azure AI Agent Service .......
# This is caculator for Azure AI Agent Service .......
# ---------- data_science_agent ----------
# [FunctionCall(id='call_kXD98vCWDFZGxLO5osDvnsxh', arguments='{"query": "What is Machine Learning?"}', name='data_science_ai_agent'), FunctionCall(id='call_pwinHzSP5OCj4kFDHoe8IrM4', arguments='{"query": "The difference between AI and ML"}', name='data_science_ai_agent'), FunctionCall(id='call_1nJZOZIHYFb0DvW3LPWpGICh', arguments='{"query": "The history of Machine Learning"}', name='data_science_ai_agent')]
# ---------- data_science_agent ----------
# [FunctionExecutionResult(content='Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machine learning systems learn from data, identify patterns, and make decisions based on that data.\n\nKey concepts in machine learning include:\n\n1. **Data**: The foundation of machine learning. Data can be structured (like tables) or unstructured (like images or text).\n\n2. **Algorithms**: These are the mathematical models that process the data. Common types of algorithms include:\n   - Supervised Learning: The model is trained on labeled data (input-output pairs).\n   - Unsupervised Learning: The model is trained on unlabeled data and must find patterns or groupings on its own.\n   - Reinforcement Learning: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties.\n\n3. **Training**: The process of feeding data into a machine learning algorithm to help it learn. This often involves adjusting parameters to minimize errors in predictions.\n\n4. **Testing and Validation**: After training, the model is tested on new data to evaluate its performance. This helps ensure that the model generalizes well to unseen data.\n\n5. **Applications**: Machine learning is used in various fields, including:\n   - Natural Language Processing (NLP)\n   - Computer Vision\n   - Recommendation Systems\n   - Fraud Detection\n   - Autonomous Vehicles\n\nOverall, machine learning enables systems to improve their performance over time as they are exposed to more data.', call_id='call_kXD98vCWDFZGxLO5osDvnsxh'), FunctionExecutionResult(content="Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.", call_id='call_pwinHzSP5OCj4kFDHoe8IrM4'), FunctionExecutionResult(content="Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.", call_id='call_1nJZOZIHYFb0DvW3LPWpGICh')]
# ---------- data_science_agent ----------
# Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machine learning systems learn from data, identify patterns, and make decisions based on that data.
#
# Key concepts in machine learning include:
#
# 1. **Data**: The foundation of machine learning. Data can be structured (like tables) or unstructured (like images or text).
#
# 2. **Algorithms**: These are the mathematical models that process the data. Common types of algorithms include:
#    - Supervised Learning: The model is trained on labeled data (input-output pairs).
#    - Unsupervised Learning: The model is trained on unlabeled data and must find patterns or groupings on its own.
#    - Reinforcement Learning: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties.
#
# 3. **Training**: The process of feeding data into a machine learning algorithm to help it learn. This often involves adjusting parameters to minimize errors in predictions.
#
# 4. **Testing and Validation**: After training, the model is tested on new data to evaluate its performance. This helps ensure that the model generalizes well to unseen data.
#
# 5. **Applications**: Machine learning is used in various fields, including:
#    - Natural Language Processing (NLP)
#    - Computer Vision
#    - Recommendation Systems
#    - Fraud Detection
#    - Autonomous Vehicles
#
# Overall, machine learning enables systems to improve their performance over time as they are exposed to more data.
# Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.
# Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.
# ---------- write_agent ----------
# # 机器学习入门指南
#
# ## 什么是机器学习？
#
# 机器学习（Machine Learning, ML）是人工智能（Artificial Intelligence, AI）的一个子集，专注于开发算法和统计模型，以使计算机能够在没有明确指令的情况下执行特定任务。不同于传统编程将每一步都明确指令给计算机，机器学习系统通过分析数据来学习，识别模式，并基于数据做出决策。
#
# 机器学习的核心概念包括：
#
# 1. **数据**：机器学习的基础。数据可以是结构化的（如表格）或非结构化的（如图像或文本）。
#
# 2. **算法**：处理数据的数学模型。常见的算法类型包括：
#    - 监督学习（Supervised Learning）：模型在标记数据（输入-输出对）上进行训练。
#    - 无监督学习（Unsupervised Learning）：模型在未标记数据上进行训练，需自行寻找模式或分组。
#    - 强化学习（Reinforcement Learning）：模型通过与环境互动并获得反馈（奖励或惩罚）来学习。
#
# 3. **训练**：将数据输入机器学习算法以帮助其学习的过程。这通常涉及调整参数，以最小化预测中的错误。
#
# 4. **测试与验证**：在训练之后，模型会在新数据上进行测试，以评估其性能。这有助于确保模型能够很好地推广到未见过的数据。
#
# 5. **应用**：机器学习在多个领域得到广泛应用，包括自然语言处理（NLP）、计算机视觉、推荐系统、欺诈检测和自动驾驶车辆等。
#
# 总的来说，机器学习使系统能够在接触更多数据时不断提升性能。
#
# ## 人工智能与机器学习的区别
#
# 在讨论机器学习时，了解人工智能与机器学习之间的区别同样重要。人工智能是一个更广泛的概念，涉及使计算机能够执行“智能”任务的所有技术。机器学习只是实现人工智能的一种方法，它使用数据驱动的学习方式来不断改进系统的表现。
#
# 人工智能可以包括规则基础的系统、专家系统、模糊逻辑以及机器学习等多个领域。因此，可以说所有机器学习都是人工智能的一部分，但并非所有人工智能都是机器学习。
#
# ## 机器学习的发展历史
#
# 机器学习的历史可以追溯到20世纪50年代。当时，计算机科学家开始探索如何使计算机模拟人类学习过程。1956年，约翰·麦卡锡（John McCarthy）在达特茅斯会议期间首次提出了“人工智能”这个术语。在接下来的数十年里，技术的进步慢慢推动了机器学习的发展。
#
# 20世纪80年代和90年代，机器学习迎来了其第二次热潮，研究者开始关注神经网络和算法的改进。随着计算能力的提升和互联网的发展，海量数据的出现为机器学习提供了丰富的“燃料”。
#
# 进入21世纪，深度学习（Deep Learning）等技术的出现使机器学习在图像识别、语音识别和自然语言处理等领域取得了突破性的成果。这一领域的发展速度之快、应用之广，使得机器学习成为当今科技的一大热点。
#
# 总结来说，机器学习不仅是一项技术，它正在改变我们的生活和工作方式。随着技术的不断进步，未来的机器学习将会更加智能化和自动化，带来更多的可能性与挑战。
#
# 希望这篇博客能帮助你更好地理解机器学习的基本概念、它与人工智能的区别以及其发展历程。让我们一起期待未来机器学习技术的不断创新与应用吧！
# This is Code Interpreter for Azure AI Agent Service .......
# ---------- save_blog_content_agent ----------
# [FunctionCall(id='call_XjXpmWGZgN1UMM8sBzaHnDyq', arguments='{"blog_content":"# 机器学习入门指南\\n\\n## 什么是机器学习？\\n\\n机器学习（Machine Learning, ML）是人工智能（Artificial Intelligence, AI）的一个子集，专注于开发算法和统计模型，以使计算机能够在没有明确指令的情况下执行特定任务。不同于传统编程将每一步都明确指令给计算机，机器学习系统通过分析数据来学习，识别模式，并基于数据做出决策。\\n\\n机器学习的核心概念包括：\\n\\n1. **数据**：机器学习的基础。数据可以是结构化的（如表格）或非结构化的（如图像或文本）。  \\n   \\n2. **算法**：处理数据的数学模型。常见的算法类型包括：  \\n   - 监督学习（Supervised Learning）：模型在标记数据（输入-输出对）上进行训练。  \\n   - 无监督学习（Unsupervised Learning）：模型在未标记数据上进行训练，需自行寻找模式或分组。  \\n   - 强化学习（Reinforcement Learning）：模型通过与环境互动并获得反馈（奖励或惩罚）来学习。\\n\\n3. **训练**：将数据输入机器学习算法以帮助其学习的过程。这通常涉及调整参数，以最小化预测中的错误。\\n\\n4. **测试与验证**：在训练之后，模型会在新数据上进行测试，以评估其性能。这有助于确保模型能够很好地推广到未见过的数据。\\n\\n5. **应用**：机器学习在多个领域得到广泛应用，包括自然语言处理（NLP）、计算机视觉、推荐系统、欺诈检测和自动驾驶车辆等。\\n\\n总的来说，机器学习使系统能够在接触更多数据时不断提升性能。\\n\\n## 人工智能与机器学习的区别\\n\\n在讨论机器学习时，了解人工智能与机器学习之间的区别同样重要。人工智能是一个更广泛的概念，涉及使计算机能够执行“智能”任务的所有技术。机器学习只是实现人工智能的一种方法，它使用数据驱动的学习方式来不断改进系统的表现。\\n\\n人工智能可以包括规则基础的系统、专家系统、模糊逻辑以及机器学习等多个领域。因此，可以说所有机器学习都是人工智能的一部分，但并非所有人工智能都是机器学习。\\n\\n## 机器学习的发展历史\\n\\n机器学习的历史可以追溯到20世纪50年代。当时，计算机科学家开始探索如何使计算机模拟人类学习过程。1956年，约翰·麦卡锡（John McCarthy）在达特茅斯会议期间首次提出了“人工智能”这个术语。在接下来的数十年里，技术的进步慢慢推动了机器学习的发展。\\n\\n20世纪80年代和90年代，机器学习迎来了其第二次热潮，研究者开始关注神经网络和算法的改进。随着计算能力的提升和互联网的发展，海量数据的出现为机器学习提供了丰富的“燃料”。\\n\\n进入21世纪，深度学习（Deep Learning）等技术的出现使机器学习在图像识别、语音识别和自然语言处理等领域取得了突破性的成果。这一领域的发展速度之快、应用之广，使得机器学习成为当今科技的一大热点。\\n\\n总结来说，机器学习不仅是一项技术，它正在改变我们的生活和工作方式。随着技术的不断进步，未来的机器学习将会更加智能化和自动化，带来更多的可能性与挑战。\\n\\n希望这篇博客能帮助你更好地理解机器学习的基本概念、它与人工智能的区别以及其发展历程。让我们一起期待未来机器学习技术的不断创新与应用吧！"}', name='save_blog_agent')]
# ---------- save_blog_content_agent ----------
# [FunctionExecutionResult(content="Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.", call_id='call_XjXpmWGZgN1UMM8sBzaHnDyq')]
# ---------- save_blog_content_agent ----------
# Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.
# ---------- data_science_agent ----------
# 由于技术限制，我无法直接保存内容。但是，我可以帮助您整理好博客内容，您可以将其复制粘贴到您所需的文档中。
#
# 下面是您所需的博客内容：
#
# ---
#
# # 机器学习入门指南
#
# ## 什么是机器学习？
#
# 机器学习（Machine Learning, ML）是人工智能（Artificial Intelligence, AI）的一个子集，专注于开发算法和统计模型，以使计算机能够在没有明确指令的情况下执行特定任务。不同于传统编程将每一步都明确指令给计算机，机器学习系统通过分析数据来学习，识别模式，并基于数据做出决策。
#
# 机器学习的核心概念包括：
#
# 1. **数据**：机器学习的基础。数据可以是结构化的（如表格）或非结构化的（如图像或文本）。
#
# 2. **算法**：处理数据的数学模型。常见的算法类型包括：
#    - 监督学习（Supervised Learning）：模型在标记数据（输入-输出对）上进行训练。
#    - 无监督学习（Unsupervised Learning）：模型在未标记数据上进行训练，需自行寻找模式或分组。
#    - 强化学习（Reinforcement Learning）：模型通过与环境互动并获得反馈（奖励或惩罚）来学习。
#
# 3. **训练**：将数据输入机器学习算法以帮助其学习的过程。这通常涉及调整参数，以最小化预测中的错误。
#
# 4. **测试与验证**：在训练之后，模型会在新数据上进行测试，以评估其性能。这有助于确保模型能够很好地推广到未见过的数据。
#
# 5. **应用**：机器学习在多个领域得到广泛应用，包括自然语言处理（NLP）、计算机视觉、推荐系统、欺诈检测和自动驾驶车辆等。
#
# 总的来说，机器学习使系统能够在接触更多数据时不断提升性能。
#
# ## 人工智能与机器学习的区别
#
# 在讨论机器学习时，了解人工智能与机器学习之间的区别同样重要。人工智能是一个更广泛的概念，涉及使计算机能够执行“智能”任务的所有技术。机器学习只是实现人工智能的一种方法，它使用数据驱动的学习方式来不断改进系统的表现。
#
# 人工智能可以包括规则基础的系统、专家系统、模糊逻辑以及机器学习等多个领域。因此，可以说所有机器学习都是人工智能的一部分，但并非所有人工智能都是机器学习。
#
# ## 机器学习的发展历史
#
# 机器学习的历史可以追溯到20世纪50年代。当时，计算机科学家开始探索如何使计算机模拟人类学习过程。1956年，约翰·麦卡锡（John McCarthy）在达特茅斯会议期间首次提出了“人工智能”这个术语。在接下来的数十年里，技术的进步慢慢推动了机器学习的发展。
#
# 20世纪80年代和90年代，机器学习迎来了其第二次热潮，研究者开始关注神经网络和算法的改进。随着计算能力的提升和互联网的发展，海量数据的出现为机器学习提供了丰富的“燃料”。
#
# 进入21世纪，深度学习（Deep Learning）等技术的出现使机器学习在图像识别、语音识别和自然语言处理等领域取得了突破性的成果。这一领域的发展速度之快、应用之广，使得机器学习成为当今科技的一大热点。
#
# 总结来说，机器学习不仅是一项技术，它正在改变我们的生活和工作方式。随着技术的不断进步，未来的机器学习将会更加智能化和自动化，带来更多的可能性与挑战。
#
# 希望这篇博客能帮助你更好地理解机器学习的基本概念、它与人工智能的区别以及其发展历程。让我们一起期待未来机器学习技术的不断创新与应用吧！
#
# ---
#
# 您可以将上述内容复制到您的博客平台或文档中。如果您需要其他帮助，请告诉我！
# ---------- write_agent ----------
# 由于技术限制，我无法直接保存内容。但是，我可以帮助您整理好博客内容，您可以将其复制粘贴到您所需的文档中。
#
# 下面是您所需的博客内容：
#
# ---
#
# # 机器学习入门指南
#
# ## 什么是机器学习？
#
# 机器学习（Machine Learning, ML）是人工智能（Artificial Intelligence, AI）的一个子集，专注于开发算法和统计模型，以使计算机能够在没有明确指令的情况下执行特定任务。不同于传统编程将每一步都明确指令给计算机，机器学习系统通过分析数据来学习，识别模式，并基于数据做出决策。
#
# 机器学习的核心概念包括：
#
# 1. **数据**：机器学习的基础。数据可以是结构化的（如表格）或非结构化的（如图像或文本）。
#
# 2. **算法**：处理数据的数学模型。常见的算法类型包括：
#    - 监督学习（Supervised Learning）：模型在标记数据（输入-输出对）上进行训练。
#    - 无监督学习（Unsupervised Learning）：模型在未标记数据上进行训练，需自行寻找模式或分组。
#    - 强化学习（Reinforcement Learning）：模型通过与环境互动并获得反馈（奖励或惩罚）来学习。
#
# 3. **训练**：将数据输入机器学习算法以帮助其学习的过程。这通常涉及调整参数，以最小化预测中的错误。
#
# 4. **测试与验证**：在训练之后，模型会在新数据上进行测试，以评估其性能。这有助于确保模型能够很好地推广到未见过的数据。
#
# 5. **应用**：机器学习在多个领域得到广泛应用，包括自然语言处理（NLP）、计算机视觉、推荐系统、欺诈检测和自动驾驶车辆等。
#
# 总的来说，机器学习使系统能够在接触更多数据时不断提升性能。
#
# ## 人工智能与机器学习的区别
#
# 在讨论机器学习时，了解人工智能与机器学习之间的区别同样重要。人工智能是一个更广泛的概念，涉及使计算机能够执行“智能”任务的所有技术。机器学习只是实现人工智能的一种方法，它使用数据驱动的学习方式来不断改进系统的表现。
#
# 人工智能可以包括规则基础的系统、专家系统、模糊逻辑以及机器学习等多个领域。因此，可以说所有机器学习都是人工智能的一部分，但并非所有人工智能都是机器学习。
#
# ## 机器学习的发展历史
#
# 机器学习的历史可以追溯到20世纪50年代。当时，计算机科学家开始探索如何使计算机模拟人类学习过程。1956年，约翰·麦卡锡（John McCarthy）在达特茅斯会议期间首次提出了“人工智能”这个术语。在接下来的数十年里，技术的进步慢慢推动了机器学习的发展。
#
# 20世纪80年代和90年代，机器学习迎来了其第二次热潮，研究者开始关注神经网络和算法的改进。随着计算能力的提升和互联网的发展，海量数据的出现为机器学习提供了丰富的“燃料”。
#
# 进入21世纪，深度学习（Deep Learning）等技术的出现使机器学习在图像识别、语音识别和自然语言处理等领域取得了突破性的成果。这一领域的发展速度之快、应用之广，使得机器学习成为当今科技的一大热点。
#
# 总结来说，机器学习不仅是一项技术，它正在改变我们的生活和工作方式。随着技术的不断进步，未来的机器学习将会更加智能化和自动化，带来更多的可能性与挑战。
#
# 希望这篇博客能帮助你更好地理解机器学习的基本概念、它与人工智能的区别以及其发展历程。让我们一起期待未来机器学习技术的不断创新与应用吧！
#
# ---
#
# 您可以将上述内容复制到您的博客平台或文档中。如果您需要其他帮助，请告诉我！
# TaskResult(messages=[TextMessage(source='user', models_usage=None, content='\n\n                    I am writing a blog about machine learning. Search for the following 3 questions and write a Chinese blog based on the search results ,save it\n                    \n                    1. What is Machine Learning?\n                    2. The difference between AI and ML\n                    3. The history of Machine Learning\n                               \n\n    ', type='TextMessage'), ToolCallRequestEvent(source='data_science_agent', models_usage=RequestUsage(prompt_tokens=127, completion_tokens=80), content=[FunctionCall(id='call_kXD98vCWDFZGxLO5osDvnsxh', arguments='{"query": "What is Machine Learning?"}', name='data_science_ai_agent'), FunctionCall(id='call_pwinHzSP5OCj4kFDHoe8IrM4', arguments='{"query": "The difference between AI and ML"}', name='data_science_ai_agent'), FunctionCall(id='call_1nJZOZIHYFb0DvW3LPWpGICh', arguments='{"query": "The history of Machine Learning"}', name='data_science_ai_agent')], type='ToolCallRequestEvent'), ToolCallExecutionEvent(source='data_science_agent', models_usage=None, content=[FunctionExecutionResult(content='Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machine learning systems learn from data, identify patterns, and make decisions based on that data.\n\nKey concepts in machine learning include:\n\n1. **Data**: The foundation of machine learning. Data can be structured (like tables) or unstructured (like images or text).\n\n2. **Algorithms**: These are the mathematical models that process the data. Common types of algorithms include:\n   - Supervised Learning: The model is trained on labeled data (input-output pairs).\n   - Unsupervised Learning: The model is trained on unlabeled data and must find patterns or groupings on its own.\n   - Reinforcement Learning: The model learns by interacting with an environment and receiving feedback in the form of rewards or penalties.\n\n3. **Training**: The process of feeding data into a machine learning algorithm to help it learn. This often involves adjusting parameters to minimize errors in predictions.\n\n4. **Testing and Validation**: After training, the model is tested on new data to evaluate its performance. This helps ensure that the model generalizes well to unseen data.\n\n5. **Applications**: Machine learning is used in various fields, including:\n   - Natural Language Processing (NLP)\n   - Computer Vision\n   - Recommendation Systems\n   - Fraud Detection\n   - Autonomous Vehicles\n\nOverall, machine learning enables systems to improve their performance over time as they are exposed to more data.', call_id='call_kXD98vCWDFZGxLO5osDvnsxh'), FunctionExecutionResult(content="Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.", call_id='call_pwinHzSP5OCj4kFDHoe8IrM4'), FunctionExecutionResult(content="Error: HTTP transport has already been closed. You may check if you're calling a function outside of the `with` of your client creation, or if you called `close()` on your client already.", call_id='call_1nJZOZIHYFb0DvW3LPWpGICh')], type='ToolCallExecutionEvent'), ToolCallSummaryMessage(source='data_science_agent', models_usage=None, content="Machine Learning (ML) is a subset of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to perform specific tasks without explicit instructions. Instead of being programmed to perform a task, machine learning systems learn from data, identify patterns, and make decisions based on that data.\n\nKey concepts in machine learning include:\n\n1. **Data**: The foundation of machine learning. D ...
